# %%
import numpy as numpy
import pandas as pd
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("C:/Users/nameera.zuha/OneDrive - SLK SOFTWARE PRIVATE LIMITED/Documents/Lung_Cancer_classif/cancer patient data sets.xlsx")
df.head()
df.tail()
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 995                     7             7                     6              7
# 996                     7             7                     6              7
# 997                     5             5                     4              6
# 998                     7             7                     6              7
# 999                     5             5                     4              6
#
#      ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 995  ...        5            3                    2         7
# 996  ...        9            6                    5         7
# 997  ...        8            7                    9         2
# 998  ...        3            2                    4         1
# 999  ...        8            7                    9         2
#
#      Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  \
# 995                      8                         2              4
# 996                      2                         4              3
# 997                      1                         4              6
# 998                      4                         2              4
# 999                      1                         4              6
#
#      Dry Cough  Snoring  Level
# 995          5        3   High
# 996          1        4   High
# 997          7        2   High
# 998          2        3   High
# 999          7        2   High
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (1000, 25)

# %% [markdown]
# Check if the values are NULL,and their data types

# %%
df.isnull().sum()
# Out:
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Patient Id                1000 non-null   object
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   int64
#  3   Air Pollution             1000 non-null   int64
#  4   Alcohol use               1000 non-null   int64
#  5   Dust Allergy              1000 non-null   int64
#  6   OccuPational Hazards      1000 non-null   int64
#  7   Genetic Risk              1000 non-null   int64
#  8   chronic Lung Disease      1000 non-null   int64
#  9   Balanced Diet             1000 non-null   int64
#  10  Obesity                   1000 non-null   int64
#  11  Smoking                   1000 non-null   int64
#  12  Passive Smoker            1000 non-null   int64
#  13  Chest Pain                1000 non-null   int64
#  14  Coughing of Blood         1000 non-null   int64
#  15  Fatigue                   1000 non-null   int64
#  16  Weight Loss               1000 non-null   int64
#  17  Shortness of Breath       1000 non-null   int64
#  18  Wheezing                  1000 non-null   int64
#  19  Swallowing Difficulty     1000 non-null   int64
#  20  Clubbing of Finger Nails  1000 non-null   int64
#  21  Frequent Cold             1000 non-null   int64
#  22  Dry Cough                 1000 non-null   int64
#  23  Snoring                   1000 non-null   int64
#  24  Level                     1000 non-null   object
# dtypes: int64(23), object(2)
# memory usage: 195.4+ KB

# %%
df.describe()
# Out:
#                Age       Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  1000.000000  1000.000000      1000.0000  1000.000000   1000.000000
# mean     37.174000     1.402000         3.8400     4.563000      5.165000
# std      12.005493     0.490547         2.0304     2.620477      1.980833
# min      14.000000     1.000000         1.0000     1.000000      1.000000
# 25%      27.750000     1.000000         2.0000     2.000000      4.000000
# 50%      36.000000     1.000000         3.0000     5.000000      6.000000
# 75%      45.000000     2.000000         6.0000     7.000000      7.000000
# max      73.000000     2.000000         8.0000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count           1000.000000   1000.000000           1000.000000
# mean               4.840000      4.580000              4.380000
# std                2.107805      2.126999              1.848518
# min                1.000000      1.000000              1.000000
# 25%                3.000000      2.000000              3.000000
# 50%                5.000000      5.000000              4.000000
# 75%                7.000000      7.000000              6.000000
# max                8.000000      7.000000              7.000000
#
#        Balanced Diet      Obesity  ...  Coughing of Blood      Fatigue  \
# count    1000.000000  1000.000000  ...        1000.000000  1000.000000
# mean        4.491000     4.465000  ...           4.859000     3.856000
# std         2.135528     2.124921  ...           2.427965     2.244616
# min         1.000000     1.000000  ...           1.000000     1.000000
# 25%         2.000000     3.000000  ...           3.000000     2.000000
# 50%         4.000000     4.000000  ...           4.000000     3.000000
# 75%         7.000000     7.000000  ...           7.000000     5.000000
# max         7.000000     7.000000  ...           9.000000     9.000000
#
#        Weight Loss  Shortness of Breath     Wheezing  Swallowing Difficulty  \
# count  1000.000000          1000.000000  1000.000000            1000.000000
# mean      3.855000             4.240000     3.777000               3.746000
# std       2.206546             2.285087     2.041921               2.270383
# min       1.000000             1.000000     1.000000               1.000000
# 25%       2.000000             2.000000     2.000000               2.000000
# 50%       3.000000             4.000000     4.000000               4.000000
# 75%       6.000000             6.000000     5.000000               5.000000
# max       8.000000             9.000000     8.000000               8.000000
#
#        Clubbing of Finger Nails  Frequent Cold    Dry Cough      Snoring
# count               1000.000000    1000.000000  1000.000000  1000.000000
# mean                   3.923000       3.536000     3.853000     2.926000
# std                    2.388048       1.832502     2.039007     1.474686
# min                    1.000000       1.000000     1.000000     1.000000
# 25%                    2.000000       2.000000     2.000000     2.000000
# 50%                    4.000000       3.000000     4.000000     3.000000
# 75%                    5.000000       5.000000     6.000000     4.000000
# max                    9.000000       7.000000     7.000000     7.000000
#
# [8 rows x 23 columns]

# %%
#min max to know range
df.agg([min,max])
# Out:
# C:\Users\nameera.zuha\AppData\Local\Temp\ipykernel_30200\4008405093.py:2: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.agg([min,max])
# C:\Users\nameera.zuha\AppData\Local\Temp\ipykernel_30200\4008405093.py:2: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.agg([min,max])
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# min         P1   14       1              1            1             1
# max       P999   73       2              8            8             8
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# min                     1             1                     1              1
# max                     8             7                     7              7
#
#      ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# min  ...        1            1                    1         1
# max  ...        9            8                    9         8
#
#      Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  \
# min                      1                         1              1
# max                      8                         9              7
#
#      Dry Cough  Snoring   Level
# min          1        1    High
# max          7        7  Medium
#
# [2 rows x 25 columns]

# %%
df.columns=df.columns.str.lower()#when i did without = the orginal df had no changes in format also important to convert better to avoid errors

# %%
df.columns
# Out:
# Index(['patient id', 'age', 'gender', 'air pollution', 'alcohol use',
#        'dust allergy', 'occupational hazards', 'genetic risk',
#        'chronic lung disease', 'balanced diet', 'obesity', 'smoking',
#        'passive smoker', 'chest pain', 'coughing of blood', 'fatigue',
#        'weight loss', 'shortness of breath', 'wheezing',
#        'swallowing difficulty', 'clubbing of finger nails', 'frequent cold',
#        'dry cough', 'snoring', 'level'],
#       dtype='object')

# %% [markdown]
# Lets observe the data according to level and gender

# %%
categories=df.columns([['Gender','level']])
plt.bart(x=categories,y=df.level,)

# %%
# # df.level
# total_sum_query = df.query("level == 'High'")['level'].value_counts()
# print(total_sum_query)
df.level.value_counts()
# Out:
# level
# High    365
# Name: count, dtype: int64
# level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='level',data=df,y='age')
plt.show()

# %%
#Gender distribution
sns.countplot(x="gender",hue="level",data=df)
plt.show()

# %%
#Smoking Distribution
sns.countplot(x="smoking",hue="level",data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['patient id', 'age', 'gender', 'air pollution', 'alcohol use',
#        'dust allergy', 'occupational hazards', 'genetic risk',
#        'chronic lung disease', 'balanced diet', 'obesity', 'smoking',
#        'passive smoker', 'chest pain', 'coughing of blood', 'fatigue',
#        'weight loss', 'shortness of breath', 'wheezing',
#        'swallowing difficulty', 'clubbing of finger nails', 'frequent cold',
#        'dry cough', 'snoring', 'level'],
#       dtype='object')
